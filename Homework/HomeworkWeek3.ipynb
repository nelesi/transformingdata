# %% [markdown]
# ***Data Transformations Week 3***

# %% [markdown]
# Define a procedure histogram() that takes a list of integers and prints a histogram to the screen. For example, histogram([4, 9, 7]) should print the following:
# ```
# ****
# *********
# *******
# ```

# %%
def histogram(an_array):
    #yourcode
    for n in an_array:
        print int(n) * '*'
    print 'End of test'
    
#tests
histogram([4, 9, 7])
histogram([9, 4, 7])

histogram([])
histogram([0])
 # hmmm what should these do?
histogram([-1]) 
 #nothing
histogram([1,2,3.14159])
 # round the last element
histogram(range(6, 300, 12))
 # show histograms from 6 to 300 in intervals of 12
# Out:
# ****
# *********
# *******
# End of test
# *********
# ****
# *******
# End of test
# End of test
#
# End of test
#
# End of test
# *
# **
# ***
# End of test
# ******
# ******************
# ******************************
# ******************************************
# ******************************************************
# ******************************************************************
# ******************************************************************************
# ******************************************************************************************
# ******************************************************************************************************
# ******************************************************************************************************************
# ******************************************************************************************************************************
# ...

# %% [markdown]
# Modify histogram() to sort the list and print the number in parentheses at the end of each bar. Use the same test set as before.

# %%
def histogram(an_array):
    #yourcode
    an_array_i = []
    for n in an_array:
        nint = int(n)
        an_array_i.append(nint)
    sorted_array = sorted(an_array_i)
    for n in sorted_array:
        print (int(n) * '*') , '(' , n , ')'
    print 'End of test'

histogram([4, 9, 7])
# Out:
# **** ( 4 )
# ******* ( 7 )
# ********* ( 9 )
# End of test

# %% [markdown]
# **Some string formatting exercises:**

# %% [markdown]
# print the numbers 0 to 1000 in 5 columns and pad each number with 0's so that they each appear as 5 digit numbers. The first two rows should look like
# ```
# 00000 00001 00002 00003 00004
# 00005 00006 00007 00008 00009
# ```

# %%
def columns(an_array):
    an_array_i = []
    line = []
    for n in an_array:
        nint = int(n)
        an_array_i.append(nint)
    for n in an_array_i:
        line.append(("{:0>5d}".format(n-4)))
        line.append(("{:0>5d}".format(n-3)))
        line.append(("{:0>5d}".format(n-2)))
        line.append(("{:0>5d}".format(n-1)))
        line.append(("{:0>5d}".format(n)))
        line.append('\n')
    print '' , ' '.join(line)
columns(range(4,1000,5))
# Out:
#  00000 00001 00002 00003 00004
#  00005 00006 00007 00008 00009
#  00010 00011 00012 00013 00014
#  00015 00016 00017 00018 00019
#  00020 00021 00022 00023 00024
#  00025 00026 00027 00028 00029
#  00030 00031 00032 00033 00034
#  00035 00036 00037 00038 00039
#  00040 00041 00042 00043 00044
#  00045 00046 00047 00048 00049
#  00050 00051 00052 00053 00054
#  00055 00056 00057 00058 00059
#  00060 00061 00062 00063 00064
#  00065 00066 00067 00068 00069
#  00070 00071 00072 00073 00074
#  00075 00076 00077 00078 00079
#  00080 00081 00082 00083 00084
#  00085 00086 00087 00088 00089
#  00090 00091 00092 00093 00094
#  00095 00096 00097 00098 00099
#  00100 00101 00102 00103 00104
#  00105 00106 00107 00108 00109
#  00110 00111 00112 00113 00114
#  00115 00116 00117 00118 00119
#  00120 00121 00122 00123 00124
#  00125 00126 00127 00128 00129
#  00130 00131 00132 00133 00134
#  00135 00136 00137 00138 00139
#  00140 00141 00142 00143 00144
#  00145 00146 00147 00148 00149
# ...

# %% [markdown]
# Define a base_converter() function that takes a decimal number and returns a string showing the original decimal number (with commas as thousands separators), the number in hex (start with '0x' and a space between each four digits), in octal, and binary.

# %%
def base_converter(decimal_integer):
    result = []
    #your code
    result.append("{0:,}".format(decimal_integer))
    result.append("{0:x}".format(decimal_integer))
    result.append("{0:o}".format(decimal_integer))
    result.append("{0:b}".format(decimal_integer))
    #end of your code
    return(result)
    
#testing
print(base_converter(0))

print(base_converter(1))

print(base_converter(15))

print(base_converter(16))

from datetime import date
print(base_converter(date.today().toordinal()))

for i in range(64):
    print(histogram(i))
    print(base_converter(i))
# Out:
# ['0', '0', '0', '0']
# ['1', '1', '1', '1']
# ['15', 'f', '17', '1111']
# ['16', '10', '20', '10000']
# ['736,012', 'b3b0c', '2635414', '10110011101100001100']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-281c309bf728> in <module>()
#      22
#      23 for i in range(64):
# ---> 24     print(histogram(i))
#      25     print(base_converter(i))
#      26
#
# <ipython-input-36-13fa4ec19c80> in histogram(an_array)
#       2     #yourcode
#       3     an_array_i = []
# ----> 4     for n in an_array:
#       5         nint = int(n)
#       6         an_array_i.append(nint)
#
# TypeError: 'int' object is not iterable

# %% [markdown]
# Define 5 dictionaries which quantify a set of at least 5 adjectives

# %%
kidsthisdays = {'Fave':'Short for "favorite". Used to be a popular expression on the West Coast primarily. Now it\'s used sarcastically at certain universities on the east coast.',
    'Vlog':'A video log. A journalistic video documentation on the web of a person\'s life, thoughts, opinions, and interests.',
    'Bae':'"Before anyone else," or a shortened version of baby or babe, another word for sweetie, and, mostly unrelated, poop in Danish.',
    'Haul':'A video showing a shopping spree in that given area, showing products or clothing that will usually be featured in future How To, or tutorial videos.',
    'Tinderella':'An attractive female discovered through the tinder dating application.'};

print kidsthisdays['Fave']

uncommon = {'Dowdy': 'Unfashionable and without style in appearance.', 
    'Platitudinous': 'Used too often to be interesting or thoughtful; hackneyed.',
    'guileless': 'Devoid of guile; innocent and without deception.',
    'mendacious': 'Not telling the truth; lying.',
    'nefarious': 'Wicked or criminal.'};

print uncommon['Dowdy']


funny = {'Bumfuzzle':'Confuse; perplex; fluster.',
         'Cattywampus':'Askew, awry, kitty-corner.',
         'Widdershins':'In a left-handed or contrary direction; counterclockwise',
         'Dumbfounded':'Astonished or amazed.',
         'Finicky':'Insisting capriciously on getting just what one wants; difficult to please; fastidious.'};

print funny['Widdershins']

touch = {'Bumpy':'Uneven, with many patches raised above the rest.',
         'Jagged':'Having rough, sharp points protruding.',
         'Gossamer':'Used to refer to something very light, thin, and insubstantial or delicate.',
         'Frothy':'Full of or covered with a mass of small bubbles.',
         'Spiky':'Like a spike or spikes or having many spikes.'};

print touch['Jagged']

emotional = {'Dazzling':'So bright as to blind someone temporarily/ Extremely clever, attractive, or impressive; brilliant; amazing',
             'Forlorn':'Sad or lonely, especially from being deserted or abandoned.',
             'Languid':'Lacking energy or disinclined to exert effort; listless.',
             'Wishy-washy':'Irresolute or indecisive.',
             'Queasy':'Experiencing nausea; nauseated.'};

print emotional['Forlorn']

# Dale, what do you mean by 'quantifying'?
# Out:
# Short for "favorite". Used to be a popular expression on the West Coast primarily. Now it's used sarcastically at certain universities on the east coast.
# Unfashionable and without style in appearance.
# In a left-handed or contrary direction; counterclockwise
# Having rough, sharp points protruding.
# Sad or lonely, especially from being deserted or abandoned.

# %% [markdown]
# **Data scraping**
#
# Use open and readlines() to read the file data/wine.txt into an array.
#
# Print all the four star reviews without any stars.
#
# Print the star ratings of all the reviews with the word "good" in them.

# %%
file = open('/Users/nelesirodriguez/Desktop/td2016/transformingdata/Homework/data/wine.txt')

# %%
wine = file.readlines()

# %%
wine
# Out:
# ['Lovely delicate, fragrant Rhone wine. Polished leather and strawberries. Perhaps a bit dilute, but good for drinking now.\t***\n',
#  'Liquorice, cherry fruit. Simple and coarse at the finish.\t**\n',
#  'Thin and completely uninspiring.\t*\n',
#  'Big, fat, textured Chardonnay - nuts and butterscotch. A slightly odd metallic/cardboard finish, but probably\t***\n',
#  'Surprisingly young feeling and drinking well, but without any great complexity. A good\t***\n',
#  'Charming, violet-fragranced nose. Classic Guigal Cote Rotie.\t****\n',
#  'Good grip and a touch of rusticity on the length. VA showing through. On the downhill slope. Just\t****\n',
#  'Just about holding together - drying out a touch at the finish. Not as good as I thought this would be. A good\t***\n',
#  'In your face wine - rather obvious and simple (although some structure did begin to show through).\t***\n',
# ...

# %%
for n in wine:
    if "good" in n:
        print n
# Out:
# Lovely delicate, fragrant Rhone wine. Polished leather and strawberries. Perhaps a bit dilute, but good for drinking now.	***
#
# Surprisingly young feeling and drinking well, but without any great complexity. A good	***
#
# Just about holding together - drying out a touch at the finish. Not as good as I thought this would be. A good	***
#
# Hot on the palate, but good balance with some maturity.	***
#
# All quite refined and delicate, appley pinot fruit, autolytic flavours. Another fairly recent disgorgement after 4 years in cellars (credit the producer for an excellent back label), it just seems a bit lacking in intensity despite the obvious quality. Perhaps this will develop but for now a good	***
#
# A bit stinky at first - resolves - tar roses but the common old Barolo oxidativeness. Tarry - quite hard work. Actually probably good. Top	***
#
# Charming tempranillo sweet strawberry nose. Good balance and elegant. A good	***
#
# ...

# %%
for n in wine:
    if "****" in n:
        print n
# Out:
# Charming, violet-fragranced nose. Classic Guigal Cote Rotie.	****
#
# Good grip and a touch of rusticity on the length. VA showing through. On the downhill slope. Just	****
#
# Gummy nose, merlot-style sweetness. Good wine, but not in a style I was expecting.	****
#
# Beautifully refined. Complex, elegant, long with the amazing precision so typical of the producer. Lovely.	****
#
# Rich again - gamy animal dry - could do with long decanting. Bare	****
#
# A slightly embarrassing start to the evening with people thinking this was vintage (1990 or 1996), possibly Krug, possibly Billecart. Lovely wine whatever. A touch of pink on the colour - a blush to cover our blushes. Elegant, good length and fine balanced acidity. A really good, cheap (under 15) fizz.	****
#
# A touch gummy and with a hint of leather. Drier than many. Robust.	****
#
# Some thought this stunk rather. I thought it the finest wine of this flight. Lovely fragrant mature Shiraz nose. At peak. Good.	****
#
# ...

# %%
for n in wine:
    if "****" in n:
        n_no = n.replace('****','')
        print n_no
# Out:
# Charming, violet-fragranced nose. Classic Guigal Cote Rotie.
#
# Good grip and a touch of rusticity on the length. VA showing through. On the downhill slope. Just
#
# Gummy nose, merlot-style sweetness. Good wine, but not in a style I was expecting.
#
# Beautifully refined. Complex, elegant, long with the amazing precision so typical of the producer. Lovely.
#
# Rich again - gamy animal dry - could do with long decanting. Bare
#
# A slightly embarrassing start to the evening with people thinking this was vintage (1990 or 1996), possibly Krug, possibly Billecart. Lovely wine whatever. A touch of pink on the colour - a blush to cover our blushes. Elegant, good length and fine balanced acidity. A really good, cheap (under 15) fizz.
#
# A touch gummy and with a hint of leather. Drier than many. Robust.
#
# Some thought this stunk rather. I thought it the finest wine of this flight. Lovely fragrant mature Shiraz nose. At peak. Good.
#
# ...
